# %%
import numpy as np
import pandas as pd

# %%
content = pd.read_csv('Datas1.csv', index_col=0, parse_dates= True)
#content['Time'] = pd.to_datetime(content['Time'])

# %%
content
# Out:
#             Mois_beans  Mois_Maize  Mois_Onion  Mois_Rice  Temp_beans  \
# Time
# 2023-07-18        33.5        33.5        33.5         39          18
# 2023-07-18        34.3        34.3        34.3         38          18
# 2023-07-18        34.7        34.7        34.7         39          18
# 2023-07-18        35.5        35.5        35.5         38          18
# 2023-07-18        36.6        36.6        36.6         37          18
# ...                ...         ...         ...        ...         ...
# 2023-08-23        74.0        63.0        67.0         93          17
# 2023-08-23        71.0        61.0        60.0         91          17
# 2023-08-23        71.0        55.0        61.0         92          17
# 2023-08-23        72.0        65.0        63.0         98          17
# 2023-08-23        67.0        59.0        65.0         84          17
#
#             Temp_Maize  Temp_Onion  Temp_Rice  Temp_Surr  Humid_beans  \
# Time
# ...

# %%
content.describe()
# Out:
#        Mois_beans  Mois_Maize  Mois_Onion   Mois_Rice  Temp_beans  Temp_Maize  \
# count  888.000000  888.000000  888.000000  888.000000  888.000000  888.000000
# mean    75.821284   63.913176   64.964414   89.583333   17.518018   17.449662
# std     17.330642   13.358364   10.577467   19.950046    0.499957    0.490243
# min      9.000000   11.400000   31.200000   13.000000   17.000000   17.000000
# 25%     76.100000   63.750000   63.000000   88.000000   17.000000   17.000000
# 50%     81.000000   68.000000   68.300000   95.000000   18.000000   17.000000
# 75%     83.000000   71.925000   71.200000   98.000000   18.000000   18.000000
# max    114.000000   77.300000   80.200000  120.000000   18.000000   18.300000
#
#        Temp_Onion   Temp_Rice   Temp_Surr  Humid_beans  Humid_Maize  \
# count  888.000000  888.000000  888.000000   888.000000   888.000000
# mean    17.516892   17.509009   17.850225    92.031532    92.004505
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(10, 4))
plt.plot(content.Mois_beans)
plt.title('Moisture content in Beans block')
plt.xlabel('Date')
plt.xticks(rotation=90)
plt.ylabel('Moisture content')
plt.show()

# %%
plt.figure(figsize=(6, 4))
#plt.hist(content.Day, content.water_level, bins=10,color='skyblue', edgecolor='black')
plt.plot(content.water_level,color='g')
plt.xlabel('Period(Day)')
plt.xticks(rotation=90)
plt.ylabel('Level mm')
plt.title('Water Level of Rice block')
plt.savefig('Water Level Rice Block')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.plot(content.Temp_beans)
plt.xlabel('Time')
plt.xticks(rotation=90)
plt.ylabel('Temp.Beans')
plt.title('Temperature of Beans block')
plt.show()

# %%
content
# Out:
#             Mois_beans  Mois_Maize  Mois_Onion  Mois_Rice  Temp_beans  \
# Time
# 2023-07-18        33.5        33.5        33.5         39          18
# 2023-07-18        34.3        34.3        34.3         38          18
# 2023-07-18        34.7        34.7        34.7         39          18
# 2023-07-18        35.5        35.5        35.5         38          18
# 2023-07-18        36.6        36.6        36.6         37          18
# ...                ...         ...         ...        ...         ...
# 2023-08-23        74.0        63.0        67.0         93          17
# 2023-08-23        71.0        61.0        60.0         91          17
# 2023-08-23        71.0        55.0        61.0         92          17
# 2023-08-23        72.0        65.0        63.0         98          17
# 2023-08-23        67.0        59.0        65.0         84          17
#
#             Temp_Maize  Temp_Onion  Temp_Rice  Temp_Surr  Humid_beans  \
# Time
# ...

# %%
content
# Out:
#             Mois_beans  Mois_Maize  Mois_Onion  Mois_Rice  Temp_beans  \
# Time
# 2023-07-18        33.5        33.5        33.5         39          18
# 2023-07-18        34.3        34.3        34.3         38          18
# 2023-07-18        34.7        34.7        34.7         39          18
# 2023-07-18        35.5        35.5        35.5         38          18
# 2023-07-18        36.6        36.6        36.6         37          18
# ...                ...         ...         ...        ...         ...
# 2023-08-23        74.0        63.0        67.0         93          17
# 2023-08-23        71.0        61.0        60.0         91          17
# 2023-08-23        71.0        55.0        61.0         92          17
# 2023-08-23        72.0        65.0        63.0         98          17
# 2023-08-23        67.0        59.0        65.0         84          17
#
#             Temp_Maize  Temp_Onion  Temp_Rice  Temp_Surr  Humid_beans  \
# Time
# ...

# %%
Moistures = content[[ 'Mois_beans', 'Mois_Maize', 'Mois_Onion', 'Mois_Rice']]

# %%
Moistures
# Out:
#             Mois_beans  Mois_Maize  Mois_Onion  Mois_Rice
# Time
# 2023-07-18        33.5        33.5        33.5         39
# 2023-07-18        34.3        34.3        34.3         38
# 2023-07-18        34.7        34.7        34.7         39
# 2023-07-18        35.5        35.5        35.5         38
# 2023-07-18        36.6        36.6        36.6         37
# ...                ...         ...         ...        ...
# 2023-08-23        74.0        63.0        67.0         93
# 2023-08-23        71.0        61.0        60.0         91
# 2023-08-23        71.0        55.0        61.0         92
# 2023-08-23        72.0        65.0        63.0         98
# 2023-08-23        67.0        59.0        65.0         84
#
# [888 rows x 4 columns]

# %%
Moistures.describe()
# Out:
#        Mois_beans  Mois_Maize  Mois_Onion   Mois_Rice
# count  888.000000  888.000000  888.000000  888.000000
# mean    75.821284   63.913176   64.964414   89.583333
# std     17.330642   13.358364   10.577467   19.950046
# min      9.000000   11.400000   31.200000   13.000000
# 25%     76.100000   63.750000   63.000000   88.000000
# 50%     81.000000   68.000000   68.300000   95.000000
# 75%     83.000000   71.925000   71.200000   98.000000
# max    114.000000   77.300000   80.200000  120.000000

# %%
import seaborn as sns
# Box plot for visual comparison
plt.figure(figsize=(8, 6))
sns.boxplot(data=Moistures)
plt.title('Soil Moisture Comparison for Four Blocks')
plt.xlabel('Block')
plt.ylabel('Soil Moisture')
plt.show()

# %%
sns.distplot(content['Mois_beans'])
legend()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12544\2926853822.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(content['Mois_beans'])
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Summary = Moistures.describe()

# %%
print("Summary Statistics:")
print(Summary)
# Out:
# Summary Statistics:
#        Mois_beans  Mois_Maize  Mois_Onion   Mois_Rice
# count  888.000000  888.000000  888.000000  888.000000
# mean    75.821284   63.913176   64.964414   89.583333
# std     17.330642   13.358364   10.577467   19.950046
# min      9.000000   11.400000   31.200000   13.000000
# 25%     76.100000   63.750000   63.000000   88.000000
# 50%     81.000000   68.000000   68.300000   95.000000
# 75%     83.000000   71.925000   71.200000   98.000000
# max    114.000000   77.300000   80.200000  120.000000

# %%
Summary
# Out:
#        Mois_beans  Mois_Maize  Mois_Onion   Mois_Rice
# count  888.000000  888.000000  888.000000  888.000000
# mean    75.821284   63.913176   64.964414   89.583333
# std     17.330642   13.358364   10.577467   19.950046
# min      9.000000   11.400000   31.200000   13.000000
# 25%     76.100000   63.750000   63.000000   88.000000
# 50%     81.000000   68.000000   68.300000   95.000000
# 75%     83.000000   71.925000   71.200000   98.000000
# max    114.000000   77.300000   80.200000  120.000000

# %%
content
# Out:
#             Mois_beans  Mois_Maize  Mois_Onion  Mois_Rice  Temp_beans  \
# Time
# 2023-07-18        33.5        33.5        33.5         39          18
# 2023-07-18        34.3        34.3        34.3         38          18
# 2023-07-18        34.7        34.7        34.7         39          18
# 2023-07-18        35.5        35.5        35.5         38          18
# 2023-07-18        36.6        36.6        36.6         37          18
# ...                ...         ...         ...        ...         ...
# 2023-08-23        74.0        63.0        67.0         93          17
# 2023-08-23        71.0        61.0        60.0         91          17
# 2023-08-23        71.0        55.0        61.0         92          17
# 2023-08-23        72.0        65.0        63.0         98          17
# 2023-08-23        67.0        59.0        65.0         84          17
#
#             Temp_Maize  Temp_Onion  Temp_Rice  Temp_Surr  Humid_beans  \
# Time
# ...

# %%
plt.figure(figsize=(10,4))
#plt.hist(content.Day, content.water_level, bins=10,color='skyblue', edgecolor='black')
plt.plot(content.water_level, linestyle='-',color='g')
plt.xlabel('Period(Day)')
plt.xticks(rotation=90)
plt.ylabel('Level mm')
plt.title('Water Level in Rice block')
plt.savefig('Water Level Rice Block')
plt.show()

# %%
Temperatures = content[['Temp_beans', 'Temp_Maize', 'Temp_Onion', 'Temp_Rice', 'Temp_Surr']]

# %%
Temperatures
# Out:
#             Temp_beans  Temp_Maize  Temp_Onion  Temp_Rice  Temp_Surr
# Time
# 2023-07-18          18        18.0          18         18         18
# 2023-07-18          18        18.0          18         18         18
# 2023-07-18          18        18.0          18         18         18
# 2023-07-18          18        18.0          18         18         18
# 2023-07-18          18        18.0          18         18         18
# ...                ...         ...         ...        ...        ...
# 2023-08-23          17        18.0          17         17         18
# 2023-08-23          17        18.0          17         17         18
# 2023-08-23          17        18.0          17         17         18
# 2023-08-23          17        17.0          17         17         18
# 2023-08-23          17        17.0          17         17         18
#
# [888 rows x 5 columns]

# %%
Temperatures.describe()
# Out:
#        Temp_beans  Temp_Maize  Temp_Onion   Temp_Rice   Temp_Surr
# count  888.000000  888.000000  888.000000  888.000000  888.000000
# mean    17.518018   17.449662   17.516892   17.509009   17.850225
# std      0.499957    0.490243    0.499996    0.500201    0.401631
# min     17.000000   17.000000   17.000000   17.000000   16.000000
# 25%     17.000000   17.000000   17.000000   17.000000   18.000000
# 50%     18.000000   17.000000   18.000000   18.000000   18.000000
# 75%     18.000000   18.000000   18.000000   18.000000   18.000000
# max     18.000000   18.300000   18.000000   18.000000   19.000000

# %%
Humidities = content[['Humid_beans', 'Humid_Maize', 'Humid_Onion','Humid_Surr']]

# %%
Humidities
# Out:
#             Humid_beans  Humid_Maize  Humid_Onion  Humid_Surr
# Time
# 2023-07-18           92           92           92          80
# 2023-07-18           92           92           92          80
# 2023-07-18           92           92           92          80
# 2023-07-18           92           92           92          80
# 2023-07-18           92           92           92          80
# ...                 ...          ...          ...         ...
# 2023-08-23           92           92           92          93
# 2023-08-23           92           92           92          93
# 2023-08-23           92           92           92          93
# 2023-08-23           92           92           92          93
# 2023-08-23           92           92           92          93
#
# [888 rows x 4 columns]

# %%
Humidities.describe()
# Out:
#        Humid_beans  Humid_Maize  Humid_Onion  Humid_Surr
# count   888.000000   888.000000   888.000000   888.00000
# mean     92.031532    92.004505    92.174550    87.63964
# std       0.174848     0.183852     0.589216     4.97374
# min      92.000000    91.000000    88.000000    76.00000
# 25%      92.000000    92.000000    92.000000    82.00000
# 50%      92.000000    92.000000    92.000000    89.00000
# 75%      92.000000    92.000000    92.000000    93.00000
# max      93.000000    93.000000    93.000000    93.00000

# %%
WaterLevel = content['water_level']

# %%
WaterLevel
# Out:
# Time
# 2023-07-18     1
# 2023-07-18     1
# 2023-07-18     1
# 2023-07-18     0
# 2023-07-18     1
#               ..
# 2023-08-23    36
# 2023-08-23    37
# 2023-08-23    35
# 2023-08-23    39
# 2023-08-23    39
# Name: water_level, Length: 888, dtype: int64

# %%
WaterLevel.describe()
# Out:
# count    888.000000
# mean      27.282658
# std       12.547275
# min        0.000000
# 25%       19.000000
# 50%       30.000000
# 75%       37.000000
# max       45.000000
# Name: water_level, dtype: float64

# %%
content
# Out:
#             Mois_beans  Mois_Maize  Mois_Onion  Mois_Rice  Temp_beans  \
# Time
# 2023-07-18        33.5        33.5        33.5         39          18
# 2023-07-18        34.3        34.3        34.3         38          18
# 2023-07-18        34.7        34.7        34.7         39          18
# 2023-07-18        35.5        35.5        35.5         38          18
# 2023-07-18        36.6        36.6        36.6         37          18
# ...                ...         ...         ...        ...         ...
# 2023-08-23        74.0        63.0        67.0         93          17
# 2023-08-23        71.0        61.0        60.0         91          17
# 2023-08-23        71.0        55.0        61.0         92          17
# 2023-08-23        72.0        65.0        63.0         98          17
# 2023-08-23        67.0        59.0        65.0         84          17
#
#             Temp_Maize  Temp_Onion  Temp_Rice  Temp_Surr  Humid_beans  \
# Time
# ...

# %%
content.plot

# %%
Moistures
# Out:
#             Mois_beans  Mois_Maize  Mois_Onion  Mois_Rice
# Time
# 2023-07-18        33.5        33.5        33.5         39
# 2023-07-18        34.3        34.3        34.3         38
# 2023-07-18        34.7        34.7        34.7         39
# 2023-07-18        35.5        35.5        35.5         38
# 2023-07-18        36.6        36.6        36.6         37
# ...                ...         ...         ...        ...
# 2023-08-23        74.0        63.0        67.0         93
# 2023-08-23        71.0        61.0        60.0         91
# 2023-08-23        71.0        55.0        61.0         92
# 2023-08-23        72.0        65.0        63.0         98
# 2023-08-23        67.0        59.0        65.0         84
#
# [888 rows x 4 columns]

# %%
from scipy import stats
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:162: UserWarning: pylab import has clobbered these variables: ['axes']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
plt.plot(Moistures.mean())
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(Moistures)
plt.show()

# %%
content
# Out:
#             Mois_beans  Mois_Maize  Mois_Onion  Mois_Rice  Temp_beans  \
# Time
# 2023-07-18        33.5        33.5        33.5         39          18
# 2023-07-18        34.3        34.3        34.3         38          18
# 2023-07-18        34.7        34.7        34.7         39          18
# 2023-07-18        35.5        35.5        35.5         38          18
# 2023-07-18        36.6        36.6        36.6         37          18
# ...                ...         ...         ...        ...         ...
# 2023-08-23        74.0        63.0        67.0         93          17
# 2023-08-23        71.0        61.0        60.0         91          17
# 2023-08-23        71.0        55.0        61.0         92          17
# 2023-08-23        72.0        65.0        63.0         98          17
# 2023-08-23        67.0        59.0        65.0         84          17
#
#             Temp_Maize  Temp_Onion  Temp_Rice  Temp_Surr  Humid_beans  \
# Time
# ...

# %%
# Create a figure and a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot data in each subplot and rotate x-axis labels
axes[0, 0].plot(content.Mois_beans)
axes[0, 0].set_title('Moisture Content of Beans')
axes[0, 0].tick_params(axis='x', rotation=90)

axes[0, 1].plot(content.Mois_Maize, 'r')
axes[0, 1].set_title('Moisture Content of Maize')
axes[0, 1].tick_params(axis='x', rotation=90)

axes[1, 0].plot(content.Mois_Onion, 'g')
axes[1, 0].set_title('Moisture Content of Onion')
axes[1, 0].tick_params(axis='x', rotation=90)

axes[1, 1].plot(content.Mois_Rice, 'y')
axes[1, 1].set_title('Moisture Content of Rice')
axes[1, 1].tick_params(axis='x', rotation=90)
# Adjust spacing between subplots
plt.tight_layout()
plt.savefig('Moisture_Content.png')
# Show the plot
plt.show()

# %%
# Create a figure and a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot data in each subplot and rotate x-axis labels
axes[0, 0].plot(content.Temp_beans)
axes[0, 0].set_title('Temperature of Beans')
axes[0, 0].tick_params(axis='x', rotation=90)

axes[0, 1].plot(content.Temp_Maize, 'r')
axes[0, 1].set_title('Temperature of Maize')
axes[0, 1].tick_params(axis='x', rotation=90)

axes[1, 0].plot(content.Temp_Onion, 'g')
axes[1, 0].set_title('Temperature of Onion')
axes[1, 0].tick_params(axis='x', rotation=90)

axes[1, 1].plot(content.Temp_Rice, 'y')
axes[1, 1].set_title('Temperature of Rice')
axes[1, 1].tick_params(axis='x', rotation=90)
# Adjust spacing between subplots
plt.tight_layout()
plt.savefig('Temperature.png')
# Show the plot
plt.show()

# %%
# Create a figure and a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# Plot data in each subplot and rotate x-axis labels
axes[0, 0].plot(content.Humid_beans)
axes[0, 0].set_title('Humidity of Beans')
axes[0, 0].tick_params(axis='x', rotation=90)

axes[0, 1].plot(content.Humid_Maize, 'r')
axes[0, 1].set_title('Humidity of Maize')
axes[0, 1].tick_params(axis='x', rotation=90)

axes[1, 0].plot(content.Humid_Onion, 'g')
axes[1, 0].set_title('Humidity of Onion')
axes[1, 0].tick_params(axis='x', rotation=90)

axes[1, 1].plot(content.Humid_Surr, 'y')
axes[1, 1].set_title('Humidity of the Surrounding')
axes[1, 1].tick_params(axis='x', rotation=90)
# Adjust spacing between subplots
plt.tight_layout()
plt.savefig('Humidity.png')
# Show the plot
plt.show()
